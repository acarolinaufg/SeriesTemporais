# %% [markdown]
# # Análise de vendas

# %%
#importando arquivos
import pandas as pd

df = pd.read_csv('alucar.csv')
df.head()
# Out:
#           mes  vendas
# 0  2017-01-31      10
# 1  2017-02-28      20
# 2  2017-03-31      33
# 3  2017-04-30      47
# 4  2017-05-31      63

# %%
#Para saber quantas linhas e colunas
print('A quantidade de linhas e colunas no arquivo é igual a: ', df.shape)
# Out:
# A quantidade de linhas e colunas no arquivo é igual a:  (24, 2)

# %%
# quantidade de dados nulos
print(' A quantidade de dados nulos é: ', df.isna().sum().sum())
# Out:
#  A quantidade de dados nulos é:  0

# %%
#A coluna de tempo precisa estar em Datetime
df['mes'] = pd.to_datetime(df['mes'])
df.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
#Para vizualização de gráficos vamos usar seaborn e matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#paleta de cores
sns.set_palette('Accent')
#adicionar grid
sns.set_style('darkgrid')
#guardar o gráfico em uma variável
ax = sns.lineplot(x='mes',y='vendas', data=df)
#setar tamanho do gráfico
ax.figure.set_size_inches(12,6)
#Setar título
ax.set_title('Vendas da companhia 2017 e 2018', loc='left', fontsize=18)
ax.set_xlabel('Meses', fontsize=14)
ax.set_ylabel('Vendas', fontsize=14)
ax=ax

# %%
df['aumento']= df['vendas'].diff()
df
# Out:
#           mes  vendas  aumento
# 0  2017-01-31      10      NaN
# 1  2017-02-28      20     10.0
# 2  2017-03-31      33     13.0
# 3  2017-04-30      47     14.0
# 4  2017-05-31      63     16.0
# 5  2017-06-30      81     18.0
# 6  2017-07-31     101     20.0
# 7  2017-08-31     124     23.0
# 8  2017-09-30     148     24.0
# 9  2017-10-31     174     26.0
# 10 2017-11-30     201     27.0
# 11 2017-12-31     230     29.0
# 12 2018-01-31     261     31.0
# 13 2018-02-28     293     32.0
# 14 2018-03-31     326     33.0
# 15 2018-04-30     362     36.0
# 16 2018-05-31     400     38.0
# 17 2018-06-30     440     40.0
# 18 2018-07-31     483     43.0
# 19 2018-08-31     527     44.0
# 20 2018-09-30     573     46.0
# 21 2018-10-31     621     48.0
# 22 2018-11-30     670     49.0
# 23 2018-12-31     721     51.0

# %%
#paleta de cores
sns.set_palette('Accent')
#adicionar grid
sns.set_style('darkgrid')
#guardar o gráfico em uma variável
ax = sns.lineplot(x='mes',y='aumento', data=df)
#setar tamanho do gráfico
ax.figure.set_size_inches(12,6)
#Setar título
ax.set_title('Aumento da companhia 2017 e 2018', loc='left', fontsize=18)
ax.set_xlabel('Meses', fontsize=14)
ax.set_ylabel('Aumento', fontsize=14)
ax=ax

# %%
#Função para fazer gráficos
def plotarGrafico(título, labelx, labely, x, y, dataset):
    #paleta de cores
    sns.set_palette('Accent')
    #adicionar grid
    sns.set_style('darkgrid')
    #guardar o gráfico em uma variável
    ax = sns.lineplot(x=x,y=y, data=dataset)
    #setar tamanho do gráfico
    ax.figure.set_size_inches(12,6)
    #Setar título
    ax.set_title(título, loc='left', fontsize=18)
    ax.set_xlabel(labelx, fontsize=14)
    ax.set_ylabel(labely, fontsize=14)
    ax=ax

# %%
#plotarGrafico('Aumento das vendas', 'tempo','aumento','mes','aumento',df)

# %%
df['aceleracao'] = df['aumento'].diff()
plotarGrafico("Aceleração das vendas", 'tempo', 'Aceleração','mes','aceleracao',df)

# %%
#Como colocar gráficos juntos
plt.figure(figsize=(16,12))
ax=plt.subplot(3,1,1)
ax.set_title('Analise empresa',fontsize=18,loc="left")
ax = sns.lineplot(x='mes',y='vendas', data=df)
ax=plt.subplot(3,1,2)
ax = sns.lineplot(x='mes',y='aumento', data=df)
ax=plt.subplot(3,1,3)
ax = sns.lineplot(x='mes',y='aceleracao', data=df)
ax=ax

# %%
#Função que plota 3 gráficos juntos
def subplot(x,y1,y2,y3,dataset,titulo):
    plt.figure(figsize=(16,12))
    ax=plt.subplot(3,1,1)
    ax.set_title(titulo,fontsize=18,loc="left")
    ax = sns.lineplot(x=x,y=y1, data=dataset)
    ax=plt.subplot(3,1,2)
    ax = sns.lineplot(x=x,y=y2, data=dataset)
    ax=plt.subplot(3,1,3)
    ax = sns.lineplot(x=x,y=y3, data=dataset)
    ax=ax

# %%
#Autocorrelação
from pandas.plotting import autocorrelation_plot

# %%
ax = plt.figure(figsize=(12,6))
autocorrelation_plot(df['vendas'])
ax=ax
